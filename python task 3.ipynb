# %%
##### def simple_interest (p,r,t):
    si=(p*r*t)/100
    return si
def compound_interest (p,r,t):
    amount=p*(1+r/100)**t
    ci=amount-p
    return ci
n=int(input("enter the number of customers"))
for i in range(n):
    print("\n customers", i+1)
    p=int(input("enter the principle:"))
    r=int(input("enter the rate:"))
    t=int(input("enter the time:"))
    si=simple_interest(p,r,t)
    ci=compound_interest(p,r,t)
    print("simple_interest", si)
    print("compound_interest", ci)
# Out:
# enter the number of customers 4
#  customers 1
# enter the principle: 5000
# enter the rate: 4
# enter the time: 8
# simple_interest 1600.0
# compound_interest 1842.845252026369
#
#  customers 2
# enter the principle: 6000
# enter the rate: 5
# enter the time: 9
# simple_interest 2700.0
# compound_interest 3307.9692958710966
#
#  customers 3
# enter the principle: 7000
# enter the rate: 5
# enter the time: 7
# simple_interest 2450.0
# compound_interest 2849.7029585937526
#
#  customers 4
# enter the principle: 4000
# enter the rate: 7
# enter the time: 5
# simple_interest 1400.0
# compound_interest 1610.2069228000018
