# %%
customer = {"name": "Amit", "balance": 5000}

# %%
if customer["balance"] > 3000:
    print("Good balance")
else:
    print("Low balance")
# Out:
# Good balance

# %%
account = ("Priya", "Savings")

# %%
if account[1] == "Savings":
    print("Savings")
# Out:
# Savings

# %%
account[1]
# Out:
# 'Savings'

# %%
customers = ["Amit", "Priya", "Rahul"]

for name in customers:
    print(name)
# Out:
# Amit
# Priya
# Rahul

# %%
transactions = [500, -200, 1000, -700]

for amount in transactions:
    if amount > 0:
        print("Credit")
    elif amount < 0:
        print("Debit")
# Out:
# Credit
# Debit
# Credit
# Debit

# %%
amounts = [2000, 6000, 4000, 8000, 1000]

for amount in amounts:
    if amount > 5000:
        print("Large")
    else:
        print("Small")
# Out:
# Small
# Large
# Small
# Large
# Small

# %%
balance = 10000

amount = int(input("Enter debit amount: "))

if amount <= balance:
    print("Debit successful")
else:
    print("Insufficient balance")
# Out:
# Enter debit amount:  6700
# Debit successful

# %%
account = {"balance": 8000}

amount = int(input("Enter amount: "))

if amount <= account["balance"]:
    account["balance"] = account["balance"] - amount
    print("New balance:", account["balance"])
else:
    print("Not enough balance")
# Out:
# Enter amount:  2000
# New balance: 6000

# %%
transactions = [("Credit", 1000), ("Debit", 500)]

for transaction in transactions:
    if transaction[0] == "Credit":
        print("Added")
    elif transaction[0] == "Debit":
        print("Deducted")
# Out:
# Added
# Deducted
