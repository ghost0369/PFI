# %%
import pandas as pd

# %%
df=pd.read_csv("financial_transactions.csv")

# %%
df
# Out:
#      Transaction_ID        Date Customer     Category     Product  Quantity  \
# 0                 1  2026-07-08      Anu  Electronics      Laptop         5
# 1                 2  2026-03-01   Nikhil   Stationery        File         1
# 2                 3  2026-05-31    Akhil   Stationery         Pen         9
# 3                 4  2026-07-15     Ravi      Grocery       Sugar         5
# 4                 5  2026-07-26    Meena      Grocery        Rice         6
# ..              ...         ...      ...          ...         ...       ...
# 495             496  2026-01-20    Priya     Clothing      Jacket         8
# 496             497  2026-02-03    Priya      Grocery        Rice         7
# 497             498  2026-08-26     Ravi  Electronics  Headphones         8
# 498             499  2026-04-02    Rahul   Stationery      Marker         8
# 499             500  2026-04-17   Swathi     Clothing       Shoes         2
#
#       Sales  Profit Payment_Method Region
# ...

# %%
df.shape
# Out:
# (500, 10)

# %%
df.head()
# Out:
#    Transaction_ID        Date Customer     Category Product  Quantity   Sales  \
# 0               1  2026-07-08      Anu  Electronics  Laptop         5  167990
# 1               2  2026-03-01   Nikhil   Stationery    File         1     111
# 2               3  2026-05-31    Akhil   Stationery     Pen         9    8181
# 3               4  2026-07-15     Ravi      Grocery   Sugar         5    3430
# 4               5  2026-07-26    Meena      Grocery    Rice         6    8748
#
#    Profit Payment_Method Region
# 0   21688    Net Banking  North
# 1      11    Net Banking  North
# 2    1051           Cash  South
# 3     436           Cash  North
# 4    1861            UPI  North

# %%
df.describe()
# Out:
#        Transaction_ID    Quantity          Sales        Profit
# count      500.000000  500.000000     500.000000     500.00000
# mean       250.500000    5.588000   77935.808000   14718.44400
# std        144.481833    2.884944  122810.672351   25053.37623
# min          1.000000    1.000000     111.000000      11.00000
# 25%        125.750000    3.000000    6823.250000    1203.75000
# 50%        250.500000    6.000000   20646.000000    3654.00000
# 75%        375.250000    8.000000   94242.000000   16099.50000
# max        500.000000   10.000000  747490.000000  156830.00000

# %%
df["Dae"]=pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Transaction_ID             int64
# Date                      object
# Customer                  object
# Category                  object
# Product                   object
# Quantity                   int64
# Sales                      int64
# Profit                     int64
# Payment_Method            object
# Region                    object
# Dae               datetime64[ns]
# dtype: object

# %%
df[df["Sales"]>6000]
# Out:
#      Transaction_ID        Date Customer     Category     Product  Quantity  \
# 0                 1  2026-07-08      Anu  Electronics      Laptop         5
# 2                 3  2026-05-31    Akhil   Stationery         Pen         9
# 4                 5  2026-07-26    Meena      Grocery        Rice         6
# 5                 6  2026-06-08     Neha      Grocery        Rice         9
# 6                 7  2026-08-07    Sneha  Electronics      Laptop         4
# ..              ...         ...      ...          ...         ...       ...
# 495             496  2026-01-20    Priya     Clothing      Jacket         8
# 496             497  2026-02-03    Priya      Grocery        Rice         7
# 497             498  2026-08-26     Ravi  Electronics  Headphones         8
# 498             499  2026-04-02    Rahul   Stationery      Marker         8
# 499             500  2026-04-17   Swathi     Clothing       Shoes         2
#
#       Sales  Profit Payment_Method Region        Dae
# ...

# %%
df[df["Profit"]>6000]
# Out:
#      Transaction_ID        Date Customer     Category     Product  Quantity  \
# 0                 1  2026-07-08      Anu  Electronics      Laptop         5
# 6                 7  2026-08-07    Sneha  Electronics      Laptop         4
# 7                 8  2026-02-23    Akhil    Furniture   Bookshelf         6
# 9                10  2026-01-17    Kiran  Electronics  Smartphone         1
# 10               11  2026-04-28    Vijay     Clothing       Dress         7
# ..              ...         ...      ...          ...         ...       ...
# 486             487  2026-02-04    Vijay    Furniture   Bookshelf         6
# 488             489  2026-03-24      Anu     Clothing       Jeans         9
# 492             493  2026-07-10   Swathi    Furniture   Bookshelf         2
# 494             495  2026-08-22     Neha  Electronics  Headphones         4
# 497             498  2026-08-26     Ravi  Electronics  Headphones         8
#
#       Sales  Profit Payment_Method Region        Dae
# ...

# %%
df[df["Transaction_ID"]==8]
# Out:
#    Transaction_ID        Date Customer   Category    Product  Quantity  Sales  \
# 7               8  2026-02-23    Akhil  Furniture  Bookshelf         6  75954
#
#    Profit Payment_Method Region        Dae
# 7   12261           Cash  South 2026-02-23

# %%
df[(df["Profit"]>6000) & (df["Payment_Method"]=="Cash")]
# Out:
#      Transaction_ID        Date Customer     Category     Product  Quantity  \
# 6                 7  2026-08-07    Sneha  Electronics      Laptop         4
# 7                 8  2026-02-23    Akhil    Furniture   Bookshelf         6
# 30               31  2026-03-17    Kiran    Furniture   Bookshelf         9
# 40               41  2026-05-24     Arun    Furniture       Table         8
# 42               43  2026-02-23    Sneha  Electronics  Headphones         6
# 88               89  2026-03-29    Priya  Electronics    Keyboard         5
# 95               96  2026-02-20    Pooja     Clothing      Jacket        10
# 109             110  2026-05-10    Akhil  Electronics  Headphones         7
# 125             126  2026-04-04    Vijay  Electronics      Laptop         5
# 127             128  2026-08-11     Ravi     Clothing      Jacket         8
# 134             135  2026-03-02     Neha  Electronics  Headphones         4
# ...

# %%
df.sort_values("Sales")
# Out:
#      Transaction_ID        Date Customer     Category     Product  Quantity  \
# 1                 2  2026-03-01   Nikhil   Stationery        File         1
# 245             246  2026-08-26    Priya      Grocery        Rice         3
# 217             218  2026-06-14   Aditya   Stationery    Notebook         1
# 389             390  2026-02-05    Pooja   Stationery        File         1
# 48               49  2026-03-30     Ravi   Stationery      Marker         1
# ..              ...         ...      ...          ...         ...       ...
# 191             192  2026-05-10   Swathi  Electronics    Keyboard         9
# 287             288  2026-01-05     Arun  Electronics    Keyboard        10
# 157             158  2026-03-20    Meena  Electronics  Headphones        10
# 169             170  2026-05-29   Swathi  Electronics      Laptop        10
# 277             278  2026-02-23     Ravi  Electronics  Smartphone        10
#
#       Sales  Profit Payment_Method Region        Dae
# ...

# %%
df.sort_values("Profit")
# Out:
#      Transaction_ID        Date Customer     Category     Product  Quantity  \
# 1                 2  2026-03-01   Nikhil   Stationery        File         1
# 217             218  2026-06-14   Aditya   Stationery    Notebook         1
# 389             390  2026-02-05    Pooja   Stationery        File         1
# 48               49  2026-03-30     Ravi   Stationery      Marker         1
# 245             246  2026-08-26    Priya      Grocery        Rice         3
# ..              ...         ...      ...          ...         ...       ...
# 157             158  2026-03-20    Meena  Electronics  Headphones        10
# 287             288  2026-01-05     Arun  Electronics    Keyboard        10
# 473             474  2026-08-11    Priya  Electronics  Smartphone         9
# 191             192  2026-05-10   Swathi  Electronics    Keyboard         9
# 298             299  2026-03-25     Arun  Electronics  Headphones        10
#
#       Sales  Profit Payment_Method Region        Dae
# ...

# %%
df.groupby("Category")[["Sales","Profit"]].sum()
# Out:
#                 Sales   Profit
# Category
# Clothing      2248310   444567
# Electronics  22256321  4258542
# Furniture    13063762  2399870
# Grocery        797596   148153
# Stationery     601915   108090

# %%
df.groupby("Product")["Sales"].sum()
# Out:
# Product
# Biscuits        201050
# Bookshelf      2564317
# Calculator       80529
# Chair          2367729
# Cooking Oil     148934
# Desk           3749482
# Dress           676986
# File            177259
# Headphones     6651629
# Jacket          440538
# Jeans           398570
# Keyboard       3210209
# Laptop         4011847
# Marker          120107
# Monitor        2561259
# Notebook         73943
# Pen             150077
# Rice            203758
# Shirt           473960
# Shoes           258256
# Smartphone     5821377
# Sofa           2264011
# Sugar           129337
# Table          2118223
# Tea             114517
# Name: Sales, dtype: int64

# %%
df.groupby("Product")[["Sales","Profit"]].sum()
# Out:
#                Sales   Profit
# Product
# Biscuits      201050    38848
# Bookshelf    2564317   422466
# Calculator     80529    18107
# Chair        2367729   404371
# Cooking Oil   148934    30229
# Desk         3749482   737419
# Dress         676986   134092
# File          177259    29767
# Headphones   6651629  1281498
# Jacket        440538    85255
# Jeans         398570    62054
# Keyboard     3210209   693752
# Laptop       4011847   661193
# Marker        120107    20967
# Monitor      2561259   496793
# Notebook       73943    13938
# Pen           150077    25311
# Rice          203758    36717
# Shirt         473960   107691
# Shoes         258256    55475
# Smartphone   5821377  1125306
# Sofa         2264011   463610
# Sugar         129337    25773
# Table        2118223   372004
# Tea           114517    16586

# %%
df.groupby("Product").agg(
Total_Sales=("Sales", "sum"),
Toatl_Profit=("Profit", "sum"),
Toatal_Quantity=("Quantity", "count"))
# Out:
#              Total_Sales  Toatl_Profit  Toatal_Quantity
# Product
# Biscuits          201050         38848               19
# Bookshelf        2564317        422466               25
# Calculator         80529         18107               13
# Chair            2367729        404371               22
# Cooking Oil       148934         30229               19
# Desk             3749482        737419               27
# Dress             676986        134092               23
# File              177259         29767               28
# Headphones       6651629       1281498               25
# Jacket            440538         85255               22
# Jeans             398570         62054               18
# Keyboard         3210209        693752               13
# Laptop           4011847        661193               19
# Marker            120107         20967               17
# Monitor          2561259        496793               17
# Notebook           73943         13938               17
# ...

# %%
sales_report=df.groupby("Category").agg(
total_sales=("Sales", "sum"),
total_Profit=("Profit", "sum"),
Toatal_Quantity=("Quantity", "count"))
sales_report
# Out:
#              total_sales  total_Profit  Toatal_Quantity
# Category
# Clothing         2248310        444567               95
# Electronics     22256321       4258542               97
# Furniture       13063762       2399870              114
# Grocery           797596        148153              100
# Stationery        601915        108090               94

# %%
df.pivot_table(index="Product",
columns="Region",
values="Sales",
aggfunc="sum")
# Out:
# Region          East    North    South     West
# Product
# Biscuits       52226    50493     6034    92297
# Bookshelf     961756   497082   170050   935429
# Calculator     23963    10151     7527    38888
# Chair         260080  1189357   472940   445352
# Cooking Oil    22207    49822    39713    37192
# Desk         1280540   436004   766461  1266477
# Dress         111722    59120   311966   194178
# File           39960    55165    53980    28154
# Headphones    810590  2790210  1235543  1815286
# Jacket        111478    51200   111008   166852
# Jeans         118516    10086   109434   160534
# Keyboard      978893   344474   193608  1693234
# Laptop        313071   645424   904350  2149002
# Marker         53255    29463    26625    10764
# Monitor       598103   295576   847515   820065
# Notebook       30017     6169    22893    14864
# Pen            51449    46146    15357    37125
# Rice           45661    61647    18862    77588
# ...
